# %%
import numpy as np
import pandas as pd
import sklearn
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

# %%
happiness = pd.read_csv("D:/Jobin/DataTrained/Project/Project 2/happiness_score_dataset.csv")
happiness
# Out:
#          Country                           Region  Happiness Rank  \
# 0    Switzerland                   Western Europe               1
# 1        Iceland                   Western Europe               2
# 2        Denmark                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4         Canada                    North America               5
# ..           ...                              ...             ...
# 153       Rwanda               Sub-Saharan Africa             154
# 154        Benin               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
# 157         Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 0              7.587         0.03411                   1.39651  1.34951
# 1              7.561         0.04884                   1.30232  1.40223
# 2              7.527         0.03328                   1.32548  1.36058
# 3              7.522         0.03880                   1.45900  1.33095
# 4              7.427         0.03553                   1.32629  1.32261
# ..               ...             ...                       ...      ...
# 153            3.465         0.03464                   0.22208  0.77370
# 154            3.340         0.03656                   0.28665  0.35386
# 155            3.006         0.05015                   0.66320  0.47489
# 156            2.905         0.08658                   0.01530  0.41587
# 157            2.839         0.06727                   0.20868  0.13995
#
#      Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                     0.94143  0.66557                        0.41978
# 1                     0.94784  0.62877                        0.14145
# 2                     0.87464  0.64938                        0.48357
# 3                     0.88521  0.66973                        0.36503
# 4                     0.90563  0.63297                        0.32957
# ..                        ...      ...                            ...
# 153                   0.42864  0.59201                        0.55191
# 154                   0.31910  0.48450                        0.08010
# 155                   0.72193  0.15684                        0.18906
# 156                   0.22396  0.11850                        0.10062
# 157                   0.28443  0.36453                        0.10731
#
#      Generosity  Dystopia Residual
# 0       0.29678            2.51738
# 1       0.43630            2.70201
# 2       0.34139            2.49204
# 3       0.34699            2.46531
# 4       0.45811            2.45176
# ..          ...                ...
# 153     0.22628            0.67042
# 154     0.18260            1.63328
# 155     0.47179            0.32858
# 156     0.19727            1.83302
# 157     0.16681            1.56726
#
# [158 rows x 12 columns]

# %% [markdown]
# Data is in descending order (1 being the highest) of ranking

# %% [markdown]
# First 5

# %%
happiness.head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
# 2      Denmark  Western Europe               3            7.527
# 3       Norway  Western Europe               4            7.522
# 4       Canada   North America               5            7.427
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# 1         0.04884                   1.30232  1.40223
# 2         0.03328                   1.32548  1.36058
# 3         0.03880                   1.45900  1.33095
# 4         0.03553                   1.32629  1.32261
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
# 2                   0.87464  0.64938                        0.48357
# 3                   0.88521  0.66973                        0.36503
# 4                   0.90563  0.63297                        0.32957
#
#    Generosity  Dystopia Residual
# 0     0.29678            2.51738
# 1     0.43630            2.70201
# 2     0.34139            2.49204
# 3     0.34699            2.46531
# 4     0.45811            2.45176

# %% [markdown]
# Last 5

# %%
happiness.tail()
# Out:
#      Country                           Region  Happiness Rank  \
# 153   Rwanda               Sub-Saharan Africa             154
# 154    Benin               Sub-Saharan Africa             155
# 155    Syria  Middle East and Northern Africa             156
# 156  Burundi               Sub-Saharan Africa             157
# 157     Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 153            3.465         0.03464                   0.22208  0.77370
# 154            3.340         0.03656                   0.28665  0.35386
# 155            3.006         0.05015                   0.66320  0.47489
# 156            2.905         0.08658                   0.01530  0.41587
# 157            2.839         0.06727                   0.20868  0.13995
#
#      Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 153                   0.42864  0.59201                        0.55191
# 154                   0.31910  0.48450                        0.08010
# 155                   0.72193  0.15684                        0.18906
# 156                   0.22396  0.11850                        0.10062
# 157                   0.28443  0.36453                        0.10731
#
#      Generosity  Dystopia Residual
# 153     0.22628            0.67042
# 154     0.18260            1.63328
# 155     0.47179            0.32858
# 156     0.19727            1.83302
# 157     0.16681            1.56726

# %%
happiness.columns
# Out:
# Index(['Country', 'Region', 'Happiness Rank', 'Happiness Score',
#        'Standard Error', 'Economy (GDP per Capita)', 'Family',
#        'Health (Life Expectancy)', 'Freedom', 'Trust (Government Corruption)',
#        'Generosity', 'Dystopia Residual'],
#       dtype='object')

# %%
happiness.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 12 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Country                        158 non-null    object
#  1   Region                         158 non-null    object
#  2   Happiness Rank                 158 non-null    int64
#  3   Happiness Score                158 non-null    float64
#  4   Standard Error                 158 non-null    float64
#  5   Economy (GDP per Capita)       158 non-null    float64
#  6   Family                         158 non-null    float64
#  7   Health (Life Expectancy)       158 non-null    float64
#  8   Freedom                        158 non-null    float64
#  9   Trust (Government Corruption)  158 non-null    float64
#  10  Generosity                     158 non-null    float64
#  11  Dystopia Residual              158 non-null    float64
# dtypes: float64(9), int64(1), object(2)
# memory usage: 14.9+ KB

# %%
sns.heatmap(happiness.isnull(), yticklabels = False, cbar = False, cmap = "viridis")

# %% [markdown]
# No null values

# %%
happiness.describe()
# Out:
#        Happiness Rank  Happiness Score  Standard Error  \
# count      158.000000       158.000000      158.000000
# mean        79.493671         5.375734        0.047885
# std         45.754363         1.145010        0.017146
# min          1.000000         2.839000        0.018480
# 25%         40.250000         4.526000        0.037268
# 50%         79.500000         5.232500        0.043940
# 75%        118.750000         6.243750        0.052300
# max        158.000000         7.587000        0.136930
#
#        Economy (GDP per Capita)      Family  Health (Life Expectancy)  \
# count                158.000000  158.000000                158.000000
# mean                   0.846137    0.991046                  0.630259
# std                    0.403121    0.272369                  0.247078
# min                    0.000000    0.000000                  0.000000
# 25%                    0.545808    0.856823                  0.439185
# 50%                    0.910245    1.029510                  0.696705
# 75%                    1.158448    1.214405                  0.811013
# max                    1.690420    1.402230                  1.025250
#
#           Freedom  Trust (Government Corruption)  Generosity  \
# count  158.000000                     158.000000  158.000000
# mean     0.428615                       0.143422    0.237296
# std      0.150693                       0.120034    0.126685
# min      0.000000                       0.000000    0.000000
# 25%      0.328330                       0.061675    0.150553
# 50%      0.435515                       0.107220    0.216130
# 75%      0.549092                       0.180255    0.309883
# max      0.669730                       0.551910    0.795880
#
#        Dystopia Residual
# count         158.000000
# mean            2.098977
# std             0.553550
# min             0.328580
# 25%             1.759410
# 50%             2.095415
# 75%             2.462415
# max             3.602140

# %%
sns.pairplot(happiness)

# %%
sns.heatmap(happiness.corr(), annot = True)

# %% [markdown]
# Happiness score is strongly dependant on Economy, Family, hyealth, and freedom. Moderately corelated to Trust, Dystopia residual. Generosity dosn't seem to have much impact

# %%
happiness = happiness.drop('Generosity', axis = 1)
happiness
# Out:
#          Country                           Region  Happiness Rank  \
# 0    Switzerland                   Western Europe               1
# 1        Iceland                   Western Europe               2
# 2        Denmark                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4         Canada                    North America               5
# ..           ...                              ...             ...
# 153       Rwanda               Sub-Saharan Africa             154
# 154        Benin               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
# 157         Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 0              7.587         0.03411                   1.39651  1.34951
# 1              7.561         0.04884                   1.30232  1.40223
# 2              7.527         0.03328                   1.32548  1.36058
# 3              7.522         0.03880                   1.45900  1.33095
# 4              7.427         0.03553                   1.32629  1.32261
# ..               ...             ...                       ...      ...
# 153            3.465         0.03464                   0.22208  0.77370
# 154            3.340         0.03656                   0.28665  0.35386
# 155            3.006         0.05015                   0.66320  0.47489
# 156            2.905         0.08658                   0.01530  0.41587
# 157            2.839         0.06727                   0.20868  0.13995
#
#      Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                     0.94143  0.66557                        0.41978
# 1                     0.94784  0.62877                        0.14145
# 2                     0.87464  0.64938                        0.48357
# 3                     0.88521  0.66973                        0.36503
# 4                     0.90563  0.63297                        0.32957
# ..                        ...      ...                            ...
# 153                   0.42864  0.59201                        0.55191
# 154                   0.31910  0.48450                        0.08010
# 155                   0.72193  0.15684                        0.18906
# 156                   0.22396  0.11850                        0.10062
# 157                   0.28443  0.36453                        0.10731
#
#      Dystopia Residual
# 0              2.51738
# 1              2.70201
# 2              2.49204
# 3              2.46531
# 4              2.45176
# ..                 ...
# 153            0.67042
# 154            1.63328
# 155            0.32858
# 156            1.83302
# 157            1.56726
#
# [158 rows x 11 columns]

# %% [markdown]
# We can also drop the columns Country, region, and rank since the score is dependent on other variables, not these

# %%
happiness = happiness.drop(['Country', 'Region', 'Happiness Rank'], axis = 1)
happiness
# Out:
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 0              7.587         0.03411                   1.39651  1.34951
# 1              7.561         0.04884                   1.30232  1.40223
# 2              7.527         0.03328                   1.32548  1.36058
# 3              7.522         0.03880                   1.45900  1.33095
# 4              7.427         0.03553                   1.32629  1.32261
# ..               ...             ...                       ...      ...
# 153            3.465         0.03464                   0.22208  0.77370
# 154            3.340         0.03656                   0.28665  0.35386
# 155            3.006         0.05015                   0.66320  0.47489
# 156            2.905         0.08658                   0.01530  0.41587
# 157            2.839         0.06727                   0.20868  0.13995
#
#      Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                     0.94143  0.66557                        0.41978
# 1                     0.94784  0.62877                        0.14145
# 2                     0.87464  0.64938                        0.48357
# 3                     0.88521  0.66973                        0.36503
# 4                     0.90563  0.63297                        0.32957
# ..                        ...      ...                            ...
# 153                   0.42864  0.59201                        0.55191
# 154                   0.31910  0.48450                        0.08010
# 155                   0.72193  0.15684                        0.18906
# 156                   0.22396  0.11850                        0.10062
# 157                   0.28443  0.36453                        0.10731
#
#      Dystopia Residual
# 0              2.51738
# 1              2.70201
# 2              2.49204
# 3              2.46531
# 4              2.45176
# ..                 ...
# 153            0.67042
# 154            1.63328
# 155            0.32858
# 156            1.83302
# 157            1.56726
#
# [158 rows x 8 columns]

# %%
happiness.hist(figsize = (12,12))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001FCD8EB9760>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001FCD8EFFC40>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001FCD8F2D2E0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001FCD8F569A0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001FCD8F8E160>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001FCD8FB6820>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001FCD8FB6910>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001FCD8FED130>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001FCD9041FD0>]],
#       dtype=object)

# %%
happiness.plot(kind = 'box', subplots = True, layout = (4,4), fontsize = 8, figsize = (12,12))
# Out:
# Happiness Score                      AxesSubplot(0.125,0.71587;0.168478x0.16413)
# Standard Error                    AxesSubplot(0.327174,0.71587;0.168478x0.16413)
# Economy (GDP per Capita)          AxesSubplot(0.529348,0.71587;0.168478x0.16413)
# Family                            AxesSubplot(0.731522,0.71587;0.168478x0.16413)
# Health (Life Expectancy)            AxesSubplot(0.125,0.518913;0.168478x0.16413)
# Freedom                          AxesSubplot(0.327174,0.518913;0.168478x0.16413)
# Trust (Government Corruption)    AxesSubplot(0.529348,0.518913;0.168478x0.16413)
# Dystopia Residual                AxesSubplot(0.731522,0.518913;0.168478x0.16413)
# dtype: object

# %% [markdown]
# There are outliers in Standard error, Trust, Family, and Dystopia Residual

# %%
from scipy.stats import zscore
z = np.abs(zscore(happiness))
z
# Out:
# array([[1.93736005, 0.80592569, 1.36962124, ..., 1.57743784, 2.30965159,
#         0.75825809],
#        [1.91458063, 0.05588945, 1.13522625, ..., 1.33245589, 0.01647953,
#         1.09285682],
#        [1.88479215, 0.8544869 , 1.19286069, ..., 1.4696591 , 2.8427738 ,
#         0.71233526],
#        ...,
#        [2.0761992 , 0.13253425, 0.45524543, ..., 1.80923785, 0.38141902,
#         3.20843049],
#        [2.1646885 , 2.26396166, 2.06756644, ..., 2.06447176, 0.35771452,
#         0.48198451],
#        [2.22251319, 1.13418227, 1.58633379, ..., 0.42662099, 0.30180313,
#         0.96361241]])

# %%
print(np.where(z>3))
# Out:
# (array([ 27,  40,  64, 115, 147, 153, 155, 157], dtype=int64), array([6, 1, 1, 1, 3, 6, 7, 3], dtype=int64))

# %%
happiness_new = happiness[(z<3).all(axis = 1)]
happiness_new
# Out:
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 0              7.587         0.03411                   1.39651  1.34951
# 1              7.561         0.04884                   1.30232  1.40223
# 2              7.527         0.03328                   1.32548  1.36058
# 3              7.522         0.03880                   1.45900  1.33095
# 4              7.427         0.03553                   1.32629  1.32261
# ..               ...             ...                       ...      ...
# 150            3.655         0.05141                   0.46534  0.77115
# 151            3.587         0.04324                   0.25812  0.85188
# 152            3.575         0.03084                   0.31982  0.30285
# 154            3.340         0.03656                   0.28665  0.35386
# 156            2.905         0.08658                   0.01530  0.41587
#
#      Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                     0.94143  0.66557                        0.41978
# 1                     0.94784  0.62877                        0.14145
# 2                     0.87464  0.64938                        0.48357
# 3                     0.88521  0.66973                        0.36503
# 4                     0.90563  0.63297                        0.32957
# ..                        ...      ...                            ...
# 150                   0.15185  0.46866                        0.17922
# 151                   0.27125  0.39493                        0.12832
# 152                   0.30335  0.23414                        0.09719
# 154                   0.31910  0.48450                        0.08010
# 156                   0.22396  0.11850                        0.10062
#
#      Dystopia Residual
# 0              2.51738
# 1              2.70201
# 2              2.49204
# 3              2.46531
# 4              2.45176
# ..                 ...
# 150            1.41723
# 151            1.46494
# 152            1.95210
# 154            1.63328
# 156            1.83302
#
# [150 rows x 8 columns]

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import StandardScaler

# %%
happiness_new = happiness_new.apply(LabelEncoder().fit_transform)

# %%
Y = happiness_new["Happiness Score"]
X = happiness_new.drop('Happiness Score', axis = 1)

# %%
Y = Y.values.reshape(-1,1)
Y.shape
# Out:
# (150, 1)

# %%
scaler = StandardScaler()
X = pd.DataFrame(scaler.fit_transform(X))

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.2, random_state = 42)
print(Y_train.shape, Y_test.shape)
# Out:
# (120, 1) (30, 1)

# %%
lnr = LinearRegression()
lnr.fit(X_train, Y_train)
# Out:
# LinearRegression()

# %%
predictions = lnr.predict(X_test)
predictions
# Out:
# array([[ 68.03098385],
#        [140.39652017],
#        [ 52.51025737],
#        [ 62.14990345],
#        [ 62.21488988],
#        [115.36066583],
#        [ 79.90710019],
#        [  8.01355324],
#        [ 95.20146378],
#        [ 63.43386185],
#        [ 47.12342714],
#        [152.06864705],
#        [111.21800714],
#        [147.77085394],
#        [131.22433849],
#        [ 93.33517093],
#        [ 45.42561967],
#        [ 77.95347348],
#        [ 91.21985902],
#        [ 21.94428557],
#        [125.35587703],
#        [ 44.42782385],
#        [122.59221048],
#        [ 33.07612247],
#        [ 24.52416265],
#        [ 11.07852887],
#        [ 43.53239003],
#        [  8.36681266],
#        [103.54065169],
#        [121.5627885 ]])

# %%
lnr_accuracy = round(lnr.score(X_train, Y_train)*100)
lnr_accuracy
# Out:
# 95.0

# %%
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score

# %%
print('Mean absolute error:', mean_absolute_error(Y_test, predictions))
print('Mean squared error:', mean_squared_error(Y_test, predictions))
print('Root Mean squared error:', np.sqrt(mean_squared_error(Y_test, predictions)))
print('R2 score is:', r2_score(Y_test, predictions))
# Out:
# Mean absolute error: 6.352758697032042
# Mean squared error: 76.15236233092702
# Root Mean squared error: 8.726532090752146
# R2 score is: 0.959417848429413

# %%
import pickle

# %%
filename = 'happiness_pickle.pkl'
pickle.dump(lnr, open(filename, 'wb'))
